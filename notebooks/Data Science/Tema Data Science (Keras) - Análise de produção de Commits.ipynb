# %%
import numpy as np
import pandas as pd
import requests as rq

url = "https://api.github.com/repos/keras-team/keras/commits?page=15per_page=100"
response = rq.get(url)
data = response.json()

# %%
data2 = pd.DataFrame(data)
data2
# Out:
#                                          sha  \
# 0   33c4e162e36452f6ad8377c05a25a20d86e754a7
# 1   1a3ee8441933fc007be6b2beb47af67998d50737
# 2   7b76bed70c1e9528bddbfe0019da550865d0963a
# 3   9a2b5092913884fa30f6790e8128e8d39655b68c
# 4   fb8fef251c817ebc9509b90e613cb5758f42803b
# 5   702862b50a973dbae6af5c76112b4fd103d4725f
# 6   7e42254118cc1284b37f81f8920177c9635bf450
# 7   b5cb82c689eac0e50522be9d2f55093dadfba24c
# 8   7a39b6c62d43c25472b2c2476bd2a8983ae4f682
# 9   e8946d5240f3b18528d4d34668ee615907879953
# 10  ecac367b2372b5f2326fcd3ddd11718323427f4e
# 11  4d59675b65b6733e525286bbd512e9d5a42f3a22
# 12  afff7b4326f380a54c73400d1e2ae03890162bdf
# 13  e25f68dc092883191519a55ab82649ea5f57c296
# 14  f242c6421fe93468064441551cdab66e70f631d8
# 15  2b1f8ed204609954ab04f7a8c123d400f929e9fb
# 16  97e3916d304c9abb2cd4c485ab996d3fbce82785
# 17  b75b2f7dcf5d3c83e33b8b2bc86f1d2543263a59
# 18  c8f66d15a717241b22ad7a65f3dec80894449fce
# 19  f295e8ee39d4ba841ac281a9337d69c7bc5e0eb6
# ...
