# %%
import numpy as np
import pandas as pd
import requests as rq

url = "https://api.github.com/repos/getify/You-Dont-Know-JS/commits?page=15per_page=100"
response = rq.get(url)
data = response.json()

# %%
data2 = pd.DataFrame(data)
data2
# Out:
#                                          sha  \
# 0   74a7f6ab97198da2d20be135c63bedf2c853bfb0
# 1   3fad40656b24578071d29af8d23fdf651316568a
# 2   4fdf7e0225b8c405f70fbb57594dd305646216c7
# 3   b9563516ebaeddc2a1cab80e75120b2bd7e8449d
# 4   5a94a7846ec95e2718d7323e531fa8b58dc2cb72
# 5   b3f7ca4980cd7b45f59a1cff2215f9f5994a32bb
# 6   119cc325f16415b6764a081ab20813295ef56682
# 7   0411e0d0cfac5e0c4d165a8d2a99cbfe70d1eda3
# 8   529671508dde28147221addbf4038bf6e2f9db31
# 9   1d80dca433619f29d0afd27aea0fdb0ce2cde5a6
# 10  0de72ebb88856a1858b1d206dd7306c7a6598634
# 11  cb2a49e27dc893d1356f809990145dd48de686b2
# 12  545b7aad3824d57b1b76e192d4ec6d0d2254d828
# 13  0424741889ae8e175a4c899cc82dd91c409273f2
# 14  733d19f6cac27d9bc74a17cdd9a81dcc5bad7d24
# 15  6af97c8ca7d08ff07666ba767d5c72a0a9cc37cd
# 16  7dec66e0f74118c11a0af587d5714e10c62d5852
# 17  f6e1e05bc2fb212bc38acfeb7461804d48975728
# 18  c3dcc597dc42bf38fbcf74ab00a196a64f9945b5
# 19  674d1d5576ce538b30c012ccc33f28c6c8719d17
# ...
