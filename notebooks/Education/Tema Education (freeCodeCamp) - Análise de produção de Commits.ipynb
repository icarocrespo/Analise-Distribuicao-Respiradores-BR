# %%
import numpy as np
import pandas as pd
import requests as rq

url = "https://api.github.com/repos/freeCodeCamp/freeCodeCamp/commits?page=15per_page=100"
response = rq.get(url)
data = response.json()

# %%
data2 = pd.DataFrame(data)
data2
# Out:
#                                          sha  \
# 0   cc39a32e8671e4a85f7aae6ded0bb091d4e648e4
# 1   6ff564605f8cc510444cdbcb4579d9a43d3e480f
# 2   e0d555fd3270570b8e7e143eba6017f7ff9ba987
# 3   a839007bfdcc3f91583fd26f48fc9f3c77c81ffe
# 4   b9bb7ce80bfb09fffac2db27b5f91d2f1f4a8e57
# 5   58d8f3f1623c315e0351108fd2319c71716d19e5
# 6   bd3a5259f5a1b07a5e899bf86a47d8a4141c2374
# 7   e7a139356239c05dcbade7d118e7d22b1a81873e
# 8   04b9cd834bd6fd9dc12ee3c16e2d4b9cb6e98387
# 9   df0a5c381f9c12a585093a44f0e8f9fe66419a23
# 10  1b39a191caa651a7718e7059103bb43760b8fd9f
# 11  ff8c7a7ee18913fd379f538a43f2b6df3c19f3c8
# 12  14478ff4e50b583930ac3bf13fc1855e0595de62
# 13  bec7b3dae423fde74bf57bce037acd075c9f43d3
# 14  fdad6c7ae428036601ca20db4fac16bab3e07969
# 15  489074cda453f73bb2d168a6a7fd09d753081274
# 16  ee9115e96ee708344cbaeb80c46a3fd6481b532b
# 17  eafd0fd1feef7feae1cac6714c64ee5fde4b1879
# 18  8460a2fee6941eb3a65bed9f5aa3dbd2f80cdb16
# 19  6ee6f6111144578c94362efbc56f4162c5a1ee03
# ...
